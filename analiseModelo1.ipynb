# %%
import matplotlib.pyplot as plt

# Dados do histórico (substitua pelos seus dados)
loss_values = [6.8974, 6.3695, 6.2229, 6.0985, 5.9656, 5.8246, 5.6764, 5.4991, 5.3004, 5.0797, 4.8482, 4.6195, 4.3912, 4.1671, 3.9478, 3.7271, 3.5148, 3.2984, 3.0803, 2.8711, 2.6634, 2.4661, 2.2699, 2.0847, 1.9107, 1.7497, 1.6025, 1.4580, 1.3305, 1.2095, 1.1051, 1.0020, 0.9094, 0.8307, 0.7518, 0.6834, 0.6158, 0.5564, 0.5050, 0.4544, 0.4090, 0.3679, 0.3306, 0.2985, 0.2681, 0.2393, 0.2143, 0.1945, 0.1744, 0.1558]
accuracy_values = [0.0413, 0.0458, 0.0525, 0.0569, 0.0622, 0.0676, 0.0760, 0.0861, 0.0987, 0.1139, 0.1307, 0.1453, 0.1661, 0.1894, 0.2162, 0.2482, 0.2920, 0.3413, 0.3890, 0.4423, 0.4906, 0.5316, 0.5823, 0.6199, 0.6587, 0.6971, 0.7322, 0.7599, 0.7866, 0.8089, 0.8322, 0.8573, 0.8741, 0.8895, 0.9078, 0.9173, 0.9267, 0.9375, 0.9456, 0.9566, 0.9616, 0.9681, 0.9728, 0.9756, 0.9801, 0.9831, 0.9857, 0.9874, 0.9877, 0.9902]

# Número de épocas
epochs = range(1, len(loss_values) + 1)

# Plotando a perda ao longo das épocas
plt.plot(epochs, loss_values, 'bo', label='Perda')
plt.title('Perda durante o Treinamento')
plt.xlabel('Épocas')
plt.ylabel('Perda')
plt.legend()
plt.show()

# Plotando a precisão ao longo das épocas
plt.plot(epochs, accuracy_values, 'ro', label='Precisão')
plt.title('Precisão durante o Treinamento')
plt.xlabel('Épocas')
plt.ylabel('Precisão')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Dados do histórico (substitua pelos seus dados)
tempo_por_epoca = [184, 208, 214, 220, 224, 234, 236, 240, 239, 249, 256, 263, 255, 251, 254, 255, 247, 248, 243, 249, 240, 236, 239, 238, 240, 237, 237, 239, 237, 241, 242, 241, 239, 246, 247, 257, 293, 297, 295, 301, 298, 316, 327, 325, 326, 333, 332, 330, 329, 336]  # Tempo por época em segundos
accuracy_values = [0.0413, 0.0458, 0.0525, 0.0569, 0.0622, 0.0676, 0.0760, 0.0861, 0.0987, 0.1139, 0.1307, 0.1453, 0.1661, 0.1894, 0.2162, 0.2482, 0.2920, 0.3413, 0.3890, 0.4423, 0.4906, 0.5316, 0.5823, 0.6199, 0.6587, 0.6971, 0.7322, 0.7599, 0.7866, 0.8089, 0.8322, 0.8573, 0.8741, 0.8895, 0.9078, 0.9173, 0.9267, 0.9375, 0.9456, 0.9566, 0.9616, 0.9681, 0.9728, 0.9756, 0.9801, 0.9831, 0.9857, 0.9874, 0.9877, 0.9902]

# Calculando o tempo acumulado
tempo_acumulado = [sum(tempo_por_epoca[:i+1]) for i in range(len(tempo_por_epoca))]

# Número de épocas
epochs = range(1, len(tempo_por_epoca) + 1)

# Plotando o tempo acumulado por época
plt.plot(epochs, tempo_acumulado, 'go', label='Tempo Acumulado (s)')
plt.title('Tempo Acumulado por Época')
plt.xlabel('Épocas')
plt.ylabel('Tempo Acumulado (s)')
plt.legend()
plt.show()

# Calculando a melhoria por tempo
melhoria_por_tempo = [accuracy_values[i] / tempo_acumulado[i] for i in range(len(accuracy_values))]

# Plotando a melhoria por tempo
plt.plot(tempo_acumulado, accuracy_values, 'yo', label='Melhoria por Tempo')
plt.title('Melhoria por Tempo')
plt.xlabel('Tempo Acumulado (s)')
plt.ylabel('Melhoria por Tempo (accuracy/s)')
plt.legend()
plt.show()
